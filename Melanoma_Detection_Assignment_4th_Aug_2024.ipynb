# %%
import pandas as pd , numpy as np, matplotlib.pyplot as plt, pathlib , os , PIL
from glob import glob
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.layers import  Activation ,  BatchNormalization , Conv2D , Dense , Dropout,Flatten , MaxPooling2D, MaxPool2D , Rescaling
from tensorflow.keras.models import Sequential
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from keras.optimizers import Adam

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
root_path = '/content/drive/MyDrive/Colab Notebooks/Dataset'
train = pathlib.Path(root_path + '/Train')
test = pathlib.Path(root_path + '/Test')

# %%
image_count_train = len(list(train.glob('*/*.jpg')))
print('Train Image Counts:--',image_count_train)
image_count_test = len(list(test.glob('*/*.jpg')))
print('Test Image Counts:--' , image_count_test)
# Out:
# Train Image Counts:-- 2239
# Test Image Counts:-- 118

# %% [markdown]
# #Lets Create a Dataset

# %% [markdown]
# Defining some parametors for loader

# %%
batch_size = 32
img_height = 180
img_width = 180

# %% [markdown]
# Use 80% of the images for training, and 20% for validation.

# %%
train_ds = tf.keras.preprocessing.image_dataset_from_directory( train,
                                                                validation_split=0.2,
                                                                subset="training",
                                                                seed=123,
                                                                image_size = (img_height, img_width),
                                                                batch_size = batch_size)
# Out:
# Found 2239 files belonging to 9 classes.
# Using 1792 files for training.

# %%
val_ds = tf.keras.preprocessing.image_dataset_from_directory(train ,
                                                             validation_split = 0.2,
                                                             subset = 'validation',
                                                             seed = 123,
                                                             image_size = ( 180 , 180),
                                                             batch_size = 32
                                                            )
# Out:
# Found 2239 files belonging to 9 classes.
# Using 447 files for validation.

# %%
test_ds = tf.keras.preprocessing.image_dataset_from_directory(test,
                                                              image_size = (180,180),
                                                              batch_size = 32)
# Out:
# Found 118 files belonging to 9 classes.

# %%
class_names = train_ds.class_names
print(class_names)
# Out:
# ['actinic keratosis', 'basal cell carcinoma', 'dermatofibroma', 'melanoma', 'nevus', 'pigmented benign keratosis', 'seborrheic keratosis', 'squamous cell carcinoma', 'vascular lesion']

# %% [markdown]
# #Visualizing the Data

# %%
plt.figure(figsize=(8, 8))
for i, j in train_ds.take(1):
  for image in range(9):
    ax = plt.subplot(3, 3, image + 1)
    plt.imshow(i[image].numpy().astype("uint8"))
    plt.title(class_names[j[image]] , size = 8)
    plt.axis("off")

# %%
plt.figure(figsize = (8,8))
for i , j in train_ds.take(1):
  for image in range(9):
    ax = plt.subplot(3,3,image+1)
    plt.imshow(i[image].numpy().astype('uint8'))
    plt.title(class_names[j[image]] , size = 8)
    plt.axis('off')

# %% [markdown]
# The image_batch is a tensor of the shape (32, 180, 180, 3). This is a batch of 32 images of shape 180x180x3 (the last dimension refers to color channels RGB). The label_batch is a tensor of the shape (32,), these are corresponding labels to the 32 images.
#
# Dataset.cache() keeps the images in memory after they're loaded off disk during the first epoch.
#
# Dataset.prefetch() overlaps data preprocessing and model execution while training.

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# #Creating the Model

# %% [markdown]
# Todo: Create a CNN model, which can accurately detect 9 classes present in the dataset. Use layers.experimental.preprocessing.Rescaling to normalize pixel values between (0,1). The RGB channel values are in the [0, 255] range. This is not ideal for a neural network. Here, it is good to standardize values to be in the [0, 1]

# %%
### Your code goes here

input_shape = (180,180,3)
lr = 1e-5
init = 'normal'
activ = 'relu'

model = Sequential()
model.add(tf.keras.layers.Rescaling(1./255, input_shape=(180, 180, 3)))
model.add(Conv2D(32, kernel_size=(3, 3), activation='relu', input_shape=input_shape))
model.add(MaxPool2D(pool_size=(2, 2)))

model.add(Conv2D(64, kernel_size=(3, 3), activation='relu'))
model.add(BatchNormalization())
model.add(MaxPool2D(pool_size=(2, 2)))

model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
model.add(BatchNormalization())
model.add(MaxPool2D(pool_size=(2, 2)))

model.add(Flatten())

model.add(Dense(512, activation='relu'))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(1))
model.add(Activation('sigmoid'))

## Number of classes is 9
model.summary()
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/preprocessing/tf_data_layer.py:19: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ rescaling (Rescaling)                │ (None, 180, 180, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d (Conv2D)                      │ (None, 178, 178, 32)        │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 89, 89, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 87, 87, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 87, 87, 64)          │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 43, 43, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 41, 41, 128)         │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_1                │ (None, 41, 41, 128)         │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (None, 20, 20, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 51200)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 512)                 │      26,214,912 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation (Activation)              │ (None, 512)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 512)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 1)                   │             513 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation_1 (Activation)            │ (None, 1)                   │               0 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 26,309,441 (100.36 MB)
#  Trainable params: 26,309,057 (100.36 MB)
#  Non-trainable params: 384 (1.50 KB)

# %% [markdown]
# #Compile the Model

# %% [markdown]
# Choose an appropirate optimiser and loss function for model training

# %%
### Todo, choose an appropirate optimiser and loss function

model.compile(optimizer= 'adam',
              loss= 'binary_crossentropy',
              metrics=['accuracy'])

# %%
# View the summary of all layers
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ rescaling (Rescaling)                │ (None, 180, 180, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d (Conv2D)                      │ (None, 178, 178, 32)        │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 89, 89, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 87, 87, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 87, 87, 64)          │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 43, 43, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 41, 41, 128)         │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_1                │ (None, 41, 41, 128)         │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (None, 20, 20, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 51200)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 512)                 │      26,214,912 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation (Activation)              │ (None, 512)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 512)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 1)                   │             513 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation_1 (Activation)            │ (None, 1)                   │               0 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 26,309,441 (100.36 MB)
#  Trainable params: 26,309,057 (100.36 MB)
#  Non-trainable params: 384 (1.50 KB)

# %% [markdown]
# Training the model

# %%
epochs = 20
batch_size = 32

history = model.fit(
  train_ds,
  batch_size=batch_size,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 383s 2s/step - accuracy: 0.1790 - loss: -19122.3457 - val_accuracy: 0.1499 - val_loss: -38714.2188
# Epoch 2/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.1853 - loss: -412039.3438 - val_accuracy: 0.1499 - val_loss: -540257.3125
# Epoch 3/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.1831 - loss: -2045798.7500 - val_accuracy: 0.1499 - val_loss: -2002914.1250
# Epoch 4/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.1709 - loss: -5534201.0000 - val_accuracy: 0.1499 - val_loss: -4945079.5000
# Epoch 5/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - accuracy: 0.1846 - loss: -11404953.0000 - val_accuracy: 0.1499 - val_loss: -11747354.0000
# Epoch 6/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.1773 - loss: -20349918.0000 - val_accuracy: 0.1499 - val_loss: -28230794.0000
# Epoch 7/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - accuracy: 0.1663 - loss: -36072736.0000 - val_accuracy: 0.1499 - val_loss: -45227800.0000
# Epoch 8/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.1763 - loss: -54200048.0000 - val_accuracy: 0.1499 - val_loss: -83406240.0000
# Epoch 9/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.1692 - loss: -80332976.0000 - val_accuracy: 0.1499 - val_loss: -64065664.0000
# Epoch 10/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.1703 - loss: -104736784.0000 - val_accuracy: 0.1499 - val_loss: -109194264.0000
# Epoch 11/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - accuracy: 0.1793 - loss: -142052208.0000 - val_accuracy: 0.1499 - val_loss: -133840840.0000
# Epoch 12/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.1707 - loss: -188149664.0000 - val_accuracy: 0.1499 - val_loss: -255555632.0000
# Epoch 13/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.1858 - loss: -236801760.0000 - val_accuracy: 0.1499 - val_loss: -204677456.0000
# Epoch 14/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.1641 - loss: -301820096.0000 - val_accuracy: 0.1499 - val_loss: -306260160.0000
# Epoch 15/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - accuracy: 0.1778 - loss: -377345216.0000 - val_accuracy: 0.1499 - val_loss: -507400672.0000
# Epoch 16/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.1820 - loss: -440073216.0000 - val_accuracy: 0.1499 - val_loss: -496750944.0000
# Epoch 17/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - accuracy: 0.1720 - loss: -544002048.0000 - val_accuracy: 0.1499 - val_loss: -684933568.0000
# Epoch 18/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.1664 - loss: -616428672.0000 - val_accuracy: 0.1499 - val_loss: -580903808.0000
# Epoch 19/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.1722 - loss: -731182080.0000 - val_accuracy: 0.1499 - val_loss: -1449932800.0000
# Epoch 20/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.1740 - loss: -842625024.0000 - val_accuracy: 0.1499 - val_loss: -978879424.0000

# %% [markdown]
# #Visualizing training results

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']


epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# #Model Overfit or Underfit?

# %%
loss, accuracy = model.evaluate(train_ds, verbose=1,)
loss_v, accuracy_v = model.evaluate(val_ds, verbose=1)

print("Accuracy: ", accuracy)
print("Validation Accuracy: ",accuracy_v)
print("Loss: ",loss)
print("Validation Loss", loss_v)


# Thus we can clearly that model Overfit and we need to chose right data augumentation strategy
# Out:
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.1598 - loss: -982708352.0000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.1446 - loss: -969895360.0000
# Accuracy:  0.1724330335855484
# Validation Accuracy:  0.14988814294338226
# Loss:  -957510208.0
# Validation Loss -978879424.0

# %%
datagen = ImageDataGenerator(
        featurewise_center=False,  # set input mean to 0 over the dataset
        samplewise_center=False,  # set each sample mean to 0
        featurewise_std_normalization=False,  # divide inputs by std of the dataset
        samplewise_std_normalization=False,  # divide each input by its std
        zca_whitening=False,  # apply ZCA whitening
        rotation_range=10,  # randomly rotate images in the range (degrees, 0 to 180)
        zoom_range = 0.1, # Randomly zoom image
        width_shift_range=0.1,  # randomly shift images horizontally (fraction of total width)
        height_shift_range=0.1,  # randomly shift images vertically (fraction of total height)
        horizontal_flip=False,  # randomly flip images
        vertical_flip=False)  # randomly flip images

image_class = ['nevus','melanoma','basal_cell_caricoma','actinic_keratosis','vasc_lesion','dermatofibroma', 'pigmented_keratosis', 'seborrheic_keratosis', 'squamous_carci']

train_batches = datagen.flow_from_directory(train,
    target_size = (180,180),
    classes = image_class,
    batch_size = 64
 )

valid_batches = datagen.flow_from_directory(test,
    target_size = (180,180),
    classes = image_class,
    batch_size = 64
)
# Out:
# Found 890 images belonging to 9 classes.
# Found 48 images belonging to 9 classes.

# %%
# visualize how your augmentation strategy works for one instance of training image.


plt.figure(figsize=(8, 8))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]] , size = 8)
    plt.axis("off")

# %% [markdown]
# #Create the model, compile and train the model

# %%
# using Dropout layer if there is an evidence of overfitting in your findings


model = Sequential()

# Increse the model size by adding another 32 layer
model.add(Conv2D(32, kernel_size=(3, 3), activation='relu', padding='same', input_shape=input_shape))
model.add(Conv2D(32, kernel_size=(3, 3), activation='relu', padding='same'))
# Max Pool size of 2*2
model.add(MaxPool2D(pool_size=(2, 2)))
# Adding Dropout Layer
model.add(Dropout(0.25))

model.add(Conv2D(64, kernel_size=(3, 3), activation='relu', padding = 'Same'))
model.add(Conv2D(64, kernel_size=(3, 3), activation='relu', padding = 'Same'))
model.add(MaxPool2D(pool_size=(2, 2)))
model.add(Dropout(0.4))

model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
model.add(MaxPool2D(pool_size=(2, 2)))
model.add(Dropout(0.4))

model.add(Flatten())

model.add(Dense(512, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(9, activation='softmax'))

model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d_3 (Conv2D)                    │ (None, 180, 180, 32)        │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_4 (Conv2D)                    │ (None, 180, 180, 32)        │           9,248 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_3 (MaxPooling2D)       │ (None, 90, 90, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 90, 90, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_5 (Conv2D)                    │ (None, 90, 90, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_6 (Conv2D)                    │ (None, 90, 90, 64)          │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_4 (MaxPooling2D)       │ (None, 45, 45, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 45, 45, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_7 (Conv2D)                    │ (None, 43, 43, 128)         │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_5 (MaxPooling2D)       │ (None, 21, 21, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_3 (Dropout)                  │ (None, 21, 21, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_1 (Flatten)                  │ (None, 56448)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 512)                 │      28,901,888 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_4 (Dropout)                  │ (None, 512)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 9)                   │           4,617 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 29,045,929 (110.80 MB)
#  Trainable params: 29,045,929 (110.80 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# #Compiling the model

# %%
optimizer = Adam(learning_rate=0.001, beta_1=0.9, beta_2=0.999, amsgrad=False)

model.compile(loss='categorical_crossentropy',
                  optimizer=optimizer,
                  metrics=['accuracy'])

# %% [markdown]
# In order to make the optimizer converge faster and closest to the global minimum of the loss function, i used an annealing method of the learning rate (LR).
#
# The LR is the step by which the optimizer walks through the 'loss landscape'. The higher LR, the bigger are the steps and the quicker is the convergence. However the sampling is very poor with an high LR and the optimizer could probably fall into a local minima

# %%
# Set a learning rate annealer
from keras.callbacks import ReduceLROnPlateau
learning_rate_reduction = ReduceLROnPlateau(monitor='val_accuracy',
    patience=3,
    verbose=1,
    factor=0.5,
    min_lr=0.00001)

# %% [markdown]
# #Training the Model

# %%
## Your code goes here, note: train your model for 20 epochs
epochs = 20
batch_size = 10
history = model.fit(train_batches,
                    epochs = epochs,
                    verbose = 1,
                    validation_data= valid_batches ,
                    callbacks= [learning_rate_reduction])
# Out:
# Epoch 1/20
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 87s 4s/step - accuracy: 0.3736 - loss: 429.4792 - val_accuracy: 0.3958 - val_loss: 1.6661 - learning_rate: 0.0010
# Epoch 2/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 81s 972ms/step - accuracy: 0.4304 - loss: 1.1047 - val_accuracy: 0.3750 - val_loss: 1.6542 - learning_rate: 0.0010
# Epoch 3/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 24s 951ms/step - accuracy: 0.4770 - loss: 1.0054 - val_accuracy: 0.3333 - val_loss: 1.6229 - learning_rate: 0.0010
# Epoch 4/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 756ms/step - accuracy: 0.5115 - loss: 0.9170
# Epoch 4: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 23s 949ms/step - accuracy: 0.5134 - loss: 0.9164 - val_accuracy: 0.3750 - val_loss: 1.4941 - learning_rate: 0.0010
# Epoch 5/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 43s 1s/step - accuracy: 0.5949 - loss: 0.8568 - val_accuracy: 0.4375 - val_loss: 1.5301 - learning_rate: 5.0000e-04
# Epoch 6/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 25s 1s/step - accuracy: 0.6036 - loss: 0.8177 - val_accuracy: 0.3958 - val_loss: 1.2968 - learning_rate: 5.0000e-04
# Epoch 7/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 42s 1s/step - accuracy: 0.6277 - loss: 0.7695 - val_accuracy: 0.4375 - val_loss: 1.2727 - learning_rate: 5.0000e-04
# Epoch 8/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 40s 985ms/step - accuracy: 0.6614 - loss: 0.7420 - val_accuracy: 0.5208 - val_loss: 1.2628 - learning_rate: 5.0000e-04
# Epoch 9/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 42s 971ms/step - accuracy: 0.6571 - loss: 0.7809 - val_accuracy: 0.4583 - val_loss: 1.1713 - learning_rate: 5.0000e-04
# Epoch 10/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 39s 974ms/step - accuracy: 0.6509 - loss: 0.7763 - val_accuracy: 0.3958 - val_loss: 1.2154 - learning_rate: 5.0000e-04
# Epoch 11/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 764ms/step - accuracy: 0.6355 - loss: 0.7422
# Epoch 11: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 41s 956ms/step - accuracy: 0.6370 - loss: 0.7411 - val_accuracy: 0.5208 - val_loss: 1.1339 - learning_rate: 5.0000e-04
# Epoch 12/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 25s 995ms/step - accuracy: 0.6770 - loss: 0.6801 - val_accuracy: 0.5000 - val_loss: 1.1998 - learning_rate: 2.5000e-04
# Epoch 13/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 41s 990ms/step - accuracy: 0.6779 - loss: 0.6917 - val_accuracy: 0.5000 - val_loss: 1.1556 - learning_rate: 2.5000e-04
# Epoch 14/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 761ms/step - accuracy: 0.7317 - loss: 0.6298
# Epoch 14: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 24s 969ms/step - accuracy: 0.7298 - loss: 0.6327 - val_accuracy: 0.5208 - val_loss: 1.1516 - learning_rate: 2.5000e-04
# Epoch 15/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 25s 987ms/step - accuracy: 0.6846 - loss: 0.6720 - val_accuracy: 0.5000 - val_loss: 1.1777 - learning_rate: 1.2500e-04
# Epoch 16/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 41s 971ms/step - accuracy: 0.7027 - loss: 0.6689 - val_accuracy: 0.5000 - val_loss: 1.1451 - learning_rate: 1.2500e-04
# Epoch 17/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 26s 1s/step - accuracy: 0.7046 - loss: 0.6350 - val_accuracy: 0.5417 - val_loss: 1.1354 - learning_rate: 1.2500e-04
# Epoch 18/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 40s 988ms/step - accuracy: 0.7057 - loss: 0.6282 - val_accuracy: 0.5208 - val_loss: 1.1392 - learning_rate: 1.2500e-04
# Epoch 19/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 24s 956ms/step - accuracy: 0.7209 - loss: 0.6522 - val_accuracy: 0.5417 - val_loss: 1.1308 - learning_rate: 1.2500e-04
# Epoch 20/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 758ms/step - accuracy: 0.7424 - loss: 0.6062
# Epoch 20: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 41s 968ms/step - accuracy: 0.7415 - loss: 0.6067 - val_accuracy: 0.5000 - val_loss: 1.1423 - learning_rate: 1.2500e-04

# %% [markdown]
# Visualizing the results

# %%
acc = history.history['accuracy']
print(history.history.keys, ":")
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
#plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()
# Out:
# <built-in method keys of dict object at 0x7b8049d0f700> :

# %% [markdown]
# #Todo: Write your findings after the model fit, see if there is an evidence of model overfit or underfit. Do you think there is some improvement now as compared to the previous model run?

# %% [markdown]
# #Todo: Find the distribution of classes in the training dataset.
#
# ##Context: Many times real life datasets can have class imbalance, one class can have proportionately higher number of samples compared to the others. Class imbalance can have a detrimental effect on the final model quality. Hence as a sanity check it becomes important to check what is the distribution of classes in the data.

# %%
data = dict()

for i in class_names:
  data[i] = []

plt.figure(figsize=(8, 8))
for images, labels in train_ds:
  for i in range(9):
    data[class_names[labels[i]]].append(images[i].numpy().astype("uint8"))

for i in data:
  data[i] = len(data[i])

f = plt.figure()
f.set_figwidth(20)
f.set_figheight(20)

plt.bar(range(len(data)), list(data.values()), align='center')
plt.xticks(range(len(data)), list(data.keys()))
plt.show()

# %% [markdown]
# ##Rectify the class imbalance

# %% [markdown]
# 1 Which class has the least number of samples? - "**Dematofibroma and Keratosiseborrheic**"
#
# 2 Which classes dominate the data in terms proportionate number of samples?  -  "**Pigmented benign keratosis**"

# %% [markdown]
# #Todo: Rectify the class imbalance

# %% [markdown]
# Context: You can use a python package known as Augmentor (https://augmentor.readthedocs.io/en/master/) to add more samples across all classes so that none of the classes have very few samples.

# %% [markdown]
# Lets see the distribution of augmented data after adding new images to the original training data.

# %% [markdown]
# Training the model on the data created using Augmentor

# %%
batch_size = 32
img_height = 180
img_width = 180

# %% [markdown]
# Creating Training Dataset

# %%
train="/content/drive/MyDrive/Colab Notebooks/Dataset/Train"
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_train,
  seed=123,
  validation_split = 0.2,
  subset = 'training',
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 2239 files belonging to 9 classes.
# Using 1792 files for training.

# %% [markdown]
# Creating Validation DataSet

# %%
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
  train,
  seed=123,
  validation_split = 0.2,
  subset = 'validation',
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 2239 files belonging to 9 classes.
# Using 447 files for validation.

# %% [markdown]
# Creating the Model

# %%
model = Sequential()

# Increse the model size by adding another 32 layer
model.add(Conv2D(32, kernel_size=(3, 3), activation='relu', padding='same', input_shape=input_shape))
model.add(Conv2D(32, kernel_size=(3, 3), activation='relu', padding='same'))

# Max Pool size of 2*2
model.add(MaxPool2D(pool_size=(2, 2)))
model.add(BatchNormalization())
# Adding Dropout Layer
model.add(Dropout(0.25))

model.add(Conv2D(64, kernel_size=(3, 3), activation='relu', padding = 'Same'))
model.add(Conv2D(64, kernel_size=(3, 3), activation='relu', padding = 'Same'))
model.add(MaxPool2D(pool_size=(2, 2)))
model.add(BatchNormalization())
model.add(Dropout(0.4))

model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
model.add(BatchNormalization())
model.add(MaxPool2D(pool_size=(2, 2)))
model.add(Dropout(0.4))

model.add(Flatten())

model.add(Dense(128, activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.5))
model.add(Dense(1, activation='softmax'))

model.summary()
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d_8 (Conv2D)                    │ (None, 180, 180, 32)        │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_9 (Conv2D)                    │ (None, 180, 180, 32)        │           9,248 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_6 (MaxPooling2D)       │ (None, 90, 90, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_2                │ (None, 90, 90, 32)          │             128 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_5 (Dropout)                  │ (None, 90, 90, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_10 (Conv2D)                   │ (None, 90, 90, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_11 (Conv2D)                   │ (None, 90, 90, 64)          │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_7 (MaxPooling2D)       │ (None, 45, 45, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_3                │ (None, 45, 45, 64)          │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_6 (Dropout)                  │ (None, 45, 45, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_12 (Conv2D)                   │ (None, 43, 43, 128)         │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_4                │ (None, 43, 43, 128)         │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_8 (MaxPooling2D)       │ (None, 21, 21, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_7 (Dropout)                  │ (None, 21, 21, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_2 (Flatten)                  │ (None, 56448)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_4 (Dense)                      │ (None, 128)                 │       7,225,472 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_5                │ (None, 128)                 │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_8 (Dropout)                  │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_5 (Dense)                      │ (None, 1)                   │             129 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 7,366,433 (28.10 MB)
#  Trainable params: 7,365,729 (28.10 MB)
#  Non-trainable params: 704 (2.75 KB)

# %% [markdown]
# Compiling the Model

# %%
optimizer = Adam(learning_rate=0.001, beta_1=0.9, beta_2=0.999, amsgrad=False)

model.compile(loss='categorical_crossentropy',
                  optimizer=optimizer,
                  metrics=['accuracy'])

# %% [markdown]
# Training the Model

# %%
epochs = 50

learning_rate_reduction = ReduceLROnPlateau(monitor='val_accuracy',
    patience=3,
    verbose=1,
    factor=0.5,
    min_lr=0.00001)

batch_size = 10
history = model.fit(train_ds,
  epochs = epochs, verbose = 1, validation_data=val_ds , callbacks=[learning_rate_reduction])
# Out:
# Epoch 1/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 44s 447ms/step - accuracy: 0.1659 - loss: 0.0000e+00 - val_accuracy: 0.1499 - val_loss: 0.0000e+00 - learning_rate: 0.0010
# Epoch 2/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 23s 402ms/step - accuracy: 0.1624 - loss: 0.0000e+00 - val_accuracy: 0.1499 - val_loss: 0.0000e+00 - learning_rate: 0.0010
# Epoch 3/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 39s 367ms/step - accuracy: 0.1640 - loss: 0.0000e+00 - val_accuracy: 0.1499 - val_loss: 0.0000e+00 - learning_rate: 0.0010
# Epoch 4/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 276ms/step - accuracy: 0.1568 - loss: 0.0000e+00
# Epoch 4: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 41s 370ms/step - accuracy: 0.1570 - loss: 0.0000e+00 - val_accuracy: 0.1499 - val_loss: 0.0000e+00 - learning_rate: 0.0010
# Epoch 5/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 41s 363ms/step - accuracy: 0.1622 - loss: 0.0000e+00 - val_accuracy: 0.1499 - val_loss: 0.0000e+00 - learning_rate: 5.0000e-04
# Epoch 6/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 21s 365ms/step - accuracy: 0.1626 - loss: 0.0000e+00 - val_accuracy: 0.1499 - val_loss: 0.0000e+00 - learning_rate: 5.0000e-04
# Epoch 7/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 278ms/step - accuracy: 0.1673 - loss: 0.0000e+00
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 21s 371ms/step - accuracy: 0.1674 - loss: 0.0000e+00 - val_accuracy: 0.1499 - val_loss: 0.0000e+00 - learning_rate: 5.0000e-04
# Epoch 8/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 21s 371ms/step - accuracy: 0.1587 - loss: 0.0000e+00 - val_accuracy: 0.1499 - val_loss: 0.0000e+00 - learning_rate: 2.5000e-04
# Epoch 9/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 41s 373ms/step - accuracy: 0.1580 - loss: 0.0000e+00 - val_accuracy: 0.1499 - val_loss: 0.0000e+00 - learning_rate: 2.5000e-04
# Epoch 10/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 288ms/step - accuracy: 0.1624 - loss: 0.0000e+00
# Epoch 10: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 22s 382ms/step - accuracy: 0.1626 - loss: 0.0000e+00 - val_accuracy: 0.1499 - val_loss: 0.0000e+00 - learning_rate: 2.5000e-04
# Epoch 11/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 41s 379ms/step - accuracy: 0.1622 - loss: 0.0000e+00 - val_accuracy: 0.1499 - val_loss: 0.0000e+00 - learning_rate: 1.2500e-04
# Epoch 12/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 38s 331ms/step - accuracy: 0.1569 - loss: 0.0000e+00 - val_accuracy: 0.1499 - val_loss: 0.0000e+00 - learning_rate: 1.2500e-04
# Epoch 13/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 275ms/step - accuracy: 0.1567 - loss: 0.0000e+00
# Epoch 13: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 21s 368ms/step - accuracy: 0.1569 - loss: 0.0000e+00 - val_accuracy: 0.1499 - val_loss: 0.0000e+00 - learning_rate: 1.2500e-04
# Epoch 14/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 19s 337ms/step - accuracy: 0.1598 - loss: 0.0000e+00 - val_accuracy: 0.1499 - val_loss: 0.0000e+00 - learning_rate: 6.2500e-05
# Epoch 15/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 22s 367ms/step - accuracy: 0.1651 - loss: 0.0000e+00 - val_accuracy: 0.1499 - val_loss: 0.0000e+00 - learning_rate: 6.2500e-05
# Epoch 16/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 276ms/step - accuracy: 0.1589 - loss: 0.0000e+00
# Epoch 16: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 41s 369ms/step - accuracy: 0.1592 - loss: 0.0000e+00 - val_accuracy: 0.1499 - val_loss: 0.0000e+00 - learning_rate: 6.2500e-05
# Epoch 17/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 42s 379ms/step - accuracy: 0.1591 - loss: 0.0000e+00 - val_accuracy: 0.1499 - val_loss: 0.0000e+00 - learning_rate: 3.1250e-05
# Epoch 18/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 40s 357ms/step - accuracy: 0.1542 - loss: 0.0000e+00 - val_accuracy: 0.1499 - val_loss: 0.0000e+00 - learning_rate: 3.1250e-05
# Epoch 19/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 276ms/step - accuracy: 0.1547 - loss: 0.0000e+00
# Epoch 19: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 21s 366ms/step - accuracy: 0.1550 - loss: 0.0000e+00 - val_accuracy: 0.1499 - val_loss: 0.0000e+00 - learning_rate: 3.1250e-05
# Epoch 20/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 21s 369ms/step - accuracy: 0.1628 - loss: 0.0000e+00 - val_accuracy: 0.1499 - val_loss: 0.0000e+00 - learning_rate: 1.5625e-05
# Epoch 21/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 40s 361ms/step - accuracy: 0.1585 - loss: 0.0000e+00 - val_accuracy: 0.1499 - val_loss: 0.0000e+00 - learning_rate: 1.5625e-05
# Epoch 22/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 275ms/step - accuracy: 0.1632 - loss: 0.0000e+00
# Epoch 22: ReduceLROnPlateau reducing learning rate to 1e-05.
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 21s 368ms/step - accuracy: 0.1634 - loss: 0.0000e+00 - val_accuracy: 0.1499 - val_loss: 0.0000e+00 - learning_rate: 1.5625e-05
# Epoch 23/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 39s 335ms/step - accuracy: 0.1593 - loss: 0.0000e+00 - val_accuracy: 0.1499 - val_loss: 0.0000e+00 - learning_rate: 1.0000e-05
# Epoch 24/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 22s 368ms/step - accuracy: 0.1618 - loss: 0.0000e+00 - val_accuracy: 0.1499 - val_loss: 0.0000e+00 - learning_rate: 1.0000e-05
# Epoch 25/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 21s 372ms/step - accuracy: 0.1610 - loss: 0.0000e+00 - val_accuracy: 0.1499 - val_loss: 0.0000e+00 - learning_rate: 1.0000e-05
# Epoch 26/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 41s 370ms/step - accuracy: 0.1614 - loss: 0.0000e+00 - val_accuracy: 0.1499 - val_loss: 0.0000e+00 - learning_rate: 1.0000e-05
# Epoch 27/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 19s 340ms/step - accuracy: 0.1638 - loss: 0.0000e+00 - val_accuracy: 0.1499 - val_loss: 0.0000e+00 - learning_rate: 1.0000e-05
# Epoch 28/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 22s 373ms/step - accuracy: 0.1604 - loss: 0.0000e+00 - val_accuracy: 0.1499 - val_loss: 0.0000e+00 - learning_rate: 1.0000e-05
# Epoch 29/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 41s 371ms/step - accuracy: 0.1607 - loss: 0.0000e+00 - val_accuracy: 0.1499 - val_loss: 0.0000e+00 - learning_rate: 1.0000e-05
# Epoch 30/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 41s 368ms/step - accuracy: 0.1578 - loss: 0.0000e+00 - val_accuracy: 0.1499 - val_loss: 0.0000e+00 - learning_rate: 1.0000e-05
# Epoch 31/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 41s 364ms/step - accuracy: 0.1630 - loss: 0.0000e+00 - val_accuracy: 0.1499 - val_loss: 0.0000e+00 - learning_rate: 1.0000e-05
# Epoch 32/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 19s 330ms/step - accuracy: 0.1551 - loss: 0.0000e+00 - val_accuracy: 0.1499 - val_loss: 0.0000e+00 - learning_rate: 1.0000e-05
# Epoch 33/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 25s 415ms/step - accuracy: 0.1719 - loss: 0.0000e+00 - val_accuracy: 0.1499 - val_loss: 0.0000e+00 - learning_rate: 1.0000e-05
# Epoch 34/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 38s 365ms/step - accuracy: 0.1587 - loss: 0.0000e+00 - val_accuracy: 0.1499 - val_loss: 0.0000e+00 - learning_rate: 1.0000e-05
# Epoch 35/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 19s 336ms/step - accuracy: 0.1635 - loss: 0.0000e+00 - val_accuracy: 0.1499 - val_loss: 0.0000e+00 - learning_rate: 1.0000e-05
# Epoch 36/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 21s 373ms/step - accuracy: 0.1616 - loss: 0.0000e+00 - val_accuracy: 0.1499 - val_loss: 0.0000e+00 - learning_rate: 1.0000e-05
# Epoch 37/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 41s 371ms/step - accuracy: 0.1648 - loss: 0.0000e+00 - val_accuracy: 0.1499 - val_loss: 0.0000e+00 - learning_rate: 1.0000e-05
# Epoch 38/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 41s 366ms/step - accuracy: 0.1648 - loss: 0.0000e+00 - val_accuracy: 0.1499 - val_loss: 0.0000e+00 - learning_rate: 1.0000e-05
# Epoch 39/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 41s 363ms/step - accuracy: 0.1593 - loss: 0.0000e+00 - val_accuracy: 0.1499 - val_loss: 0.0000e+00 - learning_rate: 1.0000e-05
# Epoch 40/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 19s 334ms/step - accuracy: 0.1550 - loss: 0.0000e+00 - val_accuracy: 0.1499 - val_loss: 0.0000e+00 - learning_rate: 1.0000e-05
# Epoch 41/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 22s 360ms/step - accuracy: 0.1586 - loss: 0.0000e+00 - val_accuracy: 0.1499 - val_loss: 0.0000e+00 - learning_rate: 1.0000e-05
# Epoch 42/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 21s 371ms/step - accuracy: 0.1629 - loss: 0.0000e+00 - val_accuracy: 0.1499 - val_loss: 0.0000e+00 - learning_rate: 1.0000e-05
# Epoch 43/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 41s 369ms/step - accuracy: 0.1651 - loss: 0.0000e+00 - val_accuracy: 0.1499 - val_loss: 0.0000e+00 - learning_rate: 1.0000e-05
# Epoch 44/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 41s 367ms/step - accuracy: 0.1553 - loss: 0.0000e+00 - val_accuracy: 0.1499 - val_loss: 0.0000e+00 - learning_rate: 1.0000e-05
# Epoch 45/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 41s 360ms/step - accuracy: 0.1621 - loss: 0.0000e+00 - val_accuracy: 0.1499 - val_loss: 0.0000e+00 - learning_rate: 1.0000e-05
# Epoch 46/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 23s 402ms/step - accuracy: 0.1624 - loss: 0.0000e+00 - val_accuracy: 0.1499 - val_loss: 0.0000e+00 - learning_rate: 1.0000e-05
# Epoch 47/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 37s 333ms/step - accuracy: 0.1639 - loss: 0.0000e+00 - val_accuracy: 0.1499 - val_loss: 0.0000e+00 - learning_rate: 1.0000e-05
# Epoch 48/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 21s 347ms/step - accuracy: 0.1649 - loss: 0.0000e+00 - val_accuracy: 0.1499 - val_loss: 0.0000e+00 - learning_rate: 1.0000e-05
# Epoch 49/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 21s 379ms/step - accuracy: 0.1525 - loss: 0.0000e+00 - val_accuracy: 0.1499 - val_loss: 0.0000e+00 - learning_rate: 1.0000e-05
# Epoch 50/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 19s 332ms/step - accuracy: 0.1641 - loss: 0.0000e+00 - val_accuracy: 0.1499 - val_loss: 0.0000e+00 - learning_rate: 1.0000e-05

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# ##Did you get rid of underfitting/overfitting? Did class rebalance help?

# %% [markdown]
# The class rebalance helped in reducing overfititng of the data and thus the loass is beng reduced But it reduced the Acurracy very low
#
# Initially we tried without the ImageDataGenerator which created data to over fit at high ratio
#
# Then we introduced dropout and ImageDataGenerator which reduced the over fit
#
# At last we tried Batch Normalization and Augumentation which really helped in carry forward
